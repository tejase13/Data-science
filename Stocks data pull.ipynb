# %%
import datetime
import numpy as np
import pandas as pd
import yfinance as yf
from datetime import date
from dateutil.relativedelta import relativedelta
from jugaad_data.nse import NSELive, index_raw, index_csv, stock_df

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
>>> import jugaad_data as jd
>>> import yfinance as yf
>>> print(f'jugaad_data version: {jd.__version__}')

>>> print(f'yfinance version: {yf.__version__}')
# Out:
# jugaad_data version: 0.24
# yfinance version: 0.2.28

# %% [markdown]
# ## 1.  Nifty data

# %% [markdown]
# ### 1.1 Live data

# %%
n = NSELive()
nifty_data = n.live_index('NIFTY 50')
print(nifty_data['name'], nifty_data['timestamp'], nifty_data['data'][0]['lastPrice'])
# Out:
# NIFTY 50 17-Aug-2023 13:36:27 19355.7

# %% [markdown]
# ### 1.2. Downloading historical NIFTY data

# %% [markdown]
# #### 1.2.1. Fetching historical data

# %%
import datetime
import pandas as pd
from dateutil.relativedelta import relativedelta
from jugaad_data.nse import index_raw

# Get from and to dates
to_date = datetime.date.today()
from_date = to_date - relativedelta(years=3)
print(from_date, to_date)

# Fetch the index data 
raw_index_data = index_raw(symbol="NIFTY 50", from_date=from_date, to_date=to_date)
# Out:
# 2020-08-17 2023-08-17

# %%
raw_index_data
# Out:
# [{'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '31 Aug 2020',
#   'OPEN': '11777.55',
#   'HIGH': '11794.25',
#   'LOW': '11325.85',
#   'CLOSE': '11387.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '28 Aug 2020',
#   'OPEN': '11602.95',
#   'HIGH': '11686.05',
#   'LOW': '11589.4',
#   'CLOSE': '11647.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '27 Aug 2020',
#   'OPEN': '11609.3',
#   'HIGH': '11617.35',
#   'LOW': '11540.6',
#   'CLOSE': '11559.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '26 Aug 2020',
#   'OPEN': '11512.85',
#   'HIGH': '11561.75',
#   'LOW': '11461.85',
#   'CLOSE': '11549.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '25 Aug 2020',
#   'OPEN': '11513.1',
#   'HIGH': '11525.9',
#   'LOW': '11423.35',
#   'CLOSE': '11472.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '24 Aug 2020',
#   'OPEN': '11412',
#   'HIGH': '11497.25',
#   'LOW': '11410.65',
#   'CLOSE': '11466.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Aug 2020',
#   'OPEN': '11409.65',
#   'HIGH': '11418.5',
#   'LOW': '11362.2',
#   'CLOSE': '11371.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '20 Aug 2020',
#   'OPEN': '11317.45',
#   'HIGH': '11361.45',
#   'LOW': '11289.8',
#   'CLOSE': '11312.20'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '19 Aug 2020',
#   'OPEN': '11452.15',
#   'HIGH': '11460.35',
#   'LOW': '11394.1',
#   'CLOSE': '11408.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '18 Aug 2020',
#   'OPEN': '11259.8',
#   'HIGH': '11401.7',
#   'LOW': '11253.15',
#   'CLOSE': '11385.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '17 Aug 2020',
#   'OPEN': '11248.9',
#   'HIGH': '11267.1',
#   'LOW': '11144.5',
#   'CLOSE': '11247.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '16 Aug 2023',
#   'OPEN': '19369.00',
#   'HIGH': '19482.75',
#   'LOW': '19317.20',
#   'CLOSE': '19465.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '14 Aug 2023',
#   'OPEN': '19383.95',
#   'HIGH': '19465.85',
#   'LOW': '19257.90',
#   'CLOSE': '19434.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '11 Aug 2023',
#   'OPEN': '19554.25',
#   'HIGH': '19557.75',
#   'LOW': '19412.75',
#   'CLOSE': '19428.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 Aug 2023',
#   'OPEN': '19605.55',
#   'HIGH': '19623.60',
#   'LOW': '19495.40',
#   'CLOSE': '19543.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Aug 2023',
#   'OPEN': '19578.80',
#   'HIGH': '19645.50',
#   'LOW': '19467.50',
#   'CLOSE': '19632.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '08 Aug 2023',
#   'OPEN': '19627.20',
#   'HIGH': '19634.40',
#   'LOW': '19533.10',
#   'CLOSE': '19570.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '07 Aug 2023',
#   'OPEN': '19576.85',
#   'HIGH': '19620.45',
#   'LOW': '19524.80',
#   'CLOSE': '19597.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '04 Aug 2023',
#   'OPEN': '19462.80',
#   'HIGH': '19538.85',
#   'LOW': '19436.45',
#   'CLOSE': '19517.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '03 Aug 2023',
#   'OPEN': '19463.75',
#   'HIGH': '19537.65',
#   'LOW': '19296.45',
#   'CLOSE': '19381.65'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '02 Aug 2023',
#   'OPEN': '19655.40',
#   'HIGH': '19678.25',
#   'LOW': '19423.55',
#   'CLOSE': '19526.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '01 Aug 2023',
#   'OPEN': '19784.00',
#   'HIGH': '19795.60',
#   'LOW': '19704.60',
#   'CLOSE': '19733.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '11 Aug 2023',
#   'OPEN': '19554.25',
#   'HIGH': '19557.75',
#   'LOW': '19412.75',
#   'CLOSE': '19428.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 Aug 2023',
#   'OPEN': '19605.55',
#   'HIGH': '19623.60',
#   'LOW': '19495.40',
#   'CLOSE': '19543.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Aug 2023',
#   'OPEN': '19578.80',
#   'HIGH': '19645.50',
#   'LOW': '19467.50',
#   'CLOSE': '19632.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '08 Aug 2023',
#   'OPEN': '19627.20',
#   'HIGH': '19634.40',
#   'LOW': '19533.10',
#   'CLOSE': '19570.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '07 Aug 2023',
#   'OPEN': '19576.85',
#   'HIGH': '19620.45',
#   'LOW': '19524.80',
#   'CLOSE': '19597.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '04 Aug 2023',
#   'OPEN': '19462.80',
#   'HIGH': '19538.85',
#   'LOW': '19436.45',
#   'CLOSE': '19517.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '03 Aug 2023',
#   'OPEN': '19463.75',
#   'HIGH': '19537.65',
#   'LOW': '19296.45',
#   'CLOSE': '19381.65'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '02 Aug 2023',
#   'OPEN': '19655.40',
#   'HIGH': '19678.25',
#   'LOW': '19423.55',
#   'CLOSE': '19526.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '01 Aug 2023',
#   'OPEN': '19784.00',
#   'HIGH': '19795.60',
#   'LOW': '19704.60',
#   'CLOSE': '19733.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '31 Jul 2023',
#   'OPEN': '19666.35',
#   'HIGH': '19772.75',
#   'LOW': '19597.60',
#   'CLOSE': '19753.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '28 Jul 2023',
#   'OPEN': '19659.75',
#   'HIGH': '19695.90',
#   'LOW': '19563.10',
#   'CLOSE': '19646.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '27 Jul 2023',
#   'OPEN': '19850.90',
#   'HIGH': '19867.55',
#   'LOW': '19603.55',
#   'CLOSE': '19659.90'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '26 Jul 2023',
#   'OPEN': '19733.35',
#   'HIGH': '19825.60',
#   'LOW': '19716.70',
#   'CLOSE': '19778.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '25 Jul 2023',
#   'OPEN': '19729.35',
#   'HIGH': '19729.35',
#   'LOW': '19615.95',
#   'CLOSE': '19680.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '24 Jul 2023',
#   'OPEN': '19748.45',
#   'HIGH': '19782.75',
#   'LOW': '19658.30',
#   'CLOSE': '19672.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Jul 2023',
#   'OPEN': '19800.45',
#   'HIGH': '19887.40',
#   'LOW': '19700.00',
#   'CLOSE': '19745.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '20 Jul 2023',
#   'OPEN': '19831.70',
#   'HIGH': '19991.85',
#   'LOW': '19758.40',
#   'CLOSE': '19979.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '19 Jul 2023',
#   'OPEN': '19802.95',
#   'HIGH': '19851.70',
#   'LOW': '19727.45',
#   'CLOSE': '19833.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '18 Jul 2023',
#   'OPEN': '19787.50',
#   'HIGH': '19819.45',
#   'LOW': '19690.20',
#   'CLOSE': '19749.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '17 Jul 2023',
#   'OPEN': '19612.15',
#   'HIGH': '19731.85',
#   'LOW': '19562.95',
#   'CLOSE': '19711.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '14 Jul 2023',
#   'OPEN': '19493.45',
#   'HIGH': '19595.35',
#   'LOW': '19433.50',
#   'CLOSE': '19564.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '13 Jul 2023',
#   'OPEN': '19495.20',
#   'HIGH': '19567.00',
#   'LOW': '19385.80',
#   'CLOSE': '19413.75'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '12 Jul 2023',
#   'OPEN': '19497.45',
#   'HIGH': '19507.70',
#   'LOW': '19361.75',
#   'CLOSE': '19384.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '11 Jul 2023',
#   'OPEN': '19427.10',
#   'HIGH': '19515.10',
#   'LOW': '19406.45',
#   'CLOSE': '19439.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 Jul 2023',
#   'OPEN': '19400.35',
#   'HIGH': '19435.85',
#   'LOW': '19327.10',
#   'CLOSE': '19355.90'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '07 Jul 2023',
#   'OPEN': '19422.80',
#   'HIGH': '19523.60',
#   'LOW': '19303.60',
#   'CLOSE': '19331.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '06 Jul 2023',
#   'OPEN': '19385.70',
#   'HIGH': '19512.20',
#   'LOW': '19373.00',
#   'CLOSE': '19497.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '05 Jul 2023',
#   'OPEN': '19405.95',
#   'HIGH': '19421.60',
#   'LOW': '19339.60',
#   'CLOSE': '19398.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '04 Jul 2023',
#   'OPEN': '19406.60',
#   'HIGH': '19434.15',
#   'LOW': '19300.00',
#   'CLOSE': '19389.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '03 Jul 2023',
#   'OPEN': '19246.50',
#   'HIGH': '19345.10',
#   'LOW': '19234.40',
#   'CLOSE': '19322.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '30 Jun 2023',
#   'OPEN': '19076.85',
#   'HIGH': '19201.70',
#   'LOW': '19024.60',
#   'CLOSE': '19189.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '28 Jun 2023',
#   'OPEN': '18908.15',
#   'HIGH': '19011.25',
#   'LOW': '18861.35',
#   'CLOSE': '18972.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '27 Jun 2023',
#   'OPEN': '18748.55',
#   'HIGH': '18829.25',
#   'LOW': '18714.25',
#   'CLOSE': '18817.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '26 Jun 2023',
#   'OPEN': '18682.35',
#   'HIGH': '18722.05',
#   'LOW': '18646.70',
#   'CLOSE': '18691.20'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '23 Jun 2023',
#   'OPEN': '18741.85',
#   'HIGH': '18756.40',
#   'LOW': '18647.10',
#   'CLOSE': '18665.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '22 Jun 2023',
#   'OPEN': '18853.60',
#   'HIGH': '18886.60',
#   'LOW': '18759.50',
#   'CLOSE': '18771.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Jun 2023',
#   'OPEN': '18849.40',
#   'HIGH': '18875.90',
#   'LOW': '18794.85',
#   'CLOSE': '18856.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '20 Jun 2023',
#   'OPEN': '18752.35',
#   'HIGH': '18839.70',
#   'LOW': '18660.65',
#   'CLOSE': '18816.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '19 Jun 2023',
#   'OPEN': '18873.30',
#   'HIGH': '18881.45',
#   'LOW': '18719.15',
#   'CLOSE': '18755.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '16 Jun 2023',
#   'OPEN': '18723.30',
#   'HIGH': '18864.70',
#   'LOW': '18710.50',
#   'CLOSE': '18826.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '15 Jun 2023',
#   'OPEN': '18774.45',
#   'HIGH': '18794.10',
#   'LOW': '18669.05',
#   'CLOSE': '18688.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '14 Jun 2023',
#   'OPEN': '18744.60',
#   'HIGH': '18769.70',
#   'LOW': '18690.00',
#   'CLOSE': '18755.90'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '13 Jun 2023',
#   'OPEN': '18631.80',
#   'HIGH': '18728.90',
#   'LOW': '18631.80',
#   'CLOSE': '18716.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '12 Jun 2023',
#   'OPEN': '18595.05',
#   'HIGH': '18633.60',
#   'LOW': '18559.75',
#   'CLOSE': '18601.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Jun 2023',
#   'OPEN': '18655.90',
#   'HIGH': '18676.65',
#   'LOW': '18555.40',
#   'CLOSE': '18563.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '08 Jun 2023',
#   'OPEN': '18725.35',
#   'HIGH': '18777.90',
#   'LOW': '18615.60',
#   'CLOSE': '18634.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '07 Jun 2023',
#   'OPEN': '18665.60',
#   'HIGH': '18738.95',
#   'LOW': '18636.00',
#   'CLOSE': '18726.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '06 Jun 2023',
#   'OPEN': '18600.80',
#   'HIGH': '18622.75',
#   'LOW': '18531.60',
#   'CLOSE': '18599.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '05 Jun 2023',
#   'OPEN': '18612.00',
#   'HIGH': '18640.15',
#   'LOW': '18582.80',
#   'CLOSE': '18593.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '02 Jun 2023',
#   'OPEN': '18550.85',
#   'HIGH': '18573.70',
#   'LOW': '18478.40',
#   'CLOSE': '18534.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '01 Jun 2023',
#   'OPEN': '18579.40',
#   'HIGH': '18580.30',
#   'LOW': '18464.55',
#   'CLOSE': '18487.75'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '30 Jun 2023',
#   'OPEN': '19076.85',
#   'HIGH': '19201.70',
#   'LOW': '19024.60',
#   'CLOSE': '19189.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '28 Jun 2023',
#   'OPEN': '18908.15',
#   'HIGH': '19011.25',
#   'LOW': '18861.35',
#   'CLOSE': '18972.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '27 Jun 2023',
#   'OPEN': '18748.55',
#   'HIGH': '18829.25',
#   'LOW': '18714.25',
#   'CLOSE': '18817.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '26 Jun 2023',
#   'OPEN': '18682.35',
#   'HIGH': '18722.05',
#   'LOW': '18646.70',
#   'CLOSE': '18691.20'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '23 Jun 2023',
#   'OPEN': '18741.85',
#   'HIGH': '18756.40',
#   'LOW': '18647.10',
#   'CLOSE': '18665.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '22 Jun 2023',
#   'OPEN': '18853.60',
#   'HIGH': '18886.60',
#   'LOW': '18759.50',
#   'CLOSE': '18771.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Jun 2023',
#   'OPEN': '18849.40',
#   'HIGH': '18875.90',
#   'LOW': '18794.85',
#   'CLOSE': '18856.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '20 Jun 2023',
#   'OPEN': '18752.35',
#   'HIGH': '18839.70',
#   'LOW': '18660.65',
#   'CLOSE': '18816.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '19 Jun 2023',
#   'OPEN': '18873.30',
#   'HIGH': '18881.45',
#   'LOW': '18719.15',
#   'CLOSE': '18755.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '16 Jun 2023',
#   'OPEN': '18723.30',
#   'HIGH': '18864.70',
#   'LOW': '18710.50',
#   'CLOSE': '18826.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '15 Jun 2023',
#   'OPEN': '18774.45',
#   'HIGH': '18794.10',
#   'LOW': '18669.05',
#   'CLOSE': '18688.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '14 Jun 2023',
#   'OPEN': '18744.60',
#   'HIGH': '18769.70',
#   'LOW': '18690.00',
#   'CLOSE': '18755.90'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '13 Jun 2023',
#   'OPEN': '18631.80',
#   'HIGH': '18728.90',
#   'LOW': '18631.80',
#   'CLOSE': '18716.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '12 Jun 2023',
#   'OPEN': '18595.05',
#   'HIGH': '18633.60',
#   'LOW': '18559.75',
#   'CLOSE': '18601.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Jun 2023',
#   'OPEN': '18655.90',
#   'HIGH': '18676.65',
#   'LOW': '18555.40',
#   'CLOSE': '18563.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '08 Jun 2023',
#   'OPEN': '18725.35',
#   'HIGH': '18777.90',
#   'LOW': '18615.60',
#   'CLOSE': '18634.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '07 Jun 2023',
#   'OPEN': '18665.60',
#   'HIGH': '18738.95',
#   'LOW': '18636.00',
#   'CLOSE': '18726.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '06 Jun 2023',
#   'OPEN': '18600.80',
#   'HIGH': '18622.75',
#   'LOW': '18531.60',
#   'CLOSE': '18599.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '05 Jun 2023',
#   'OPEN': '18612.00',
#   'HIGH': '18640.15',
#   'LOW': '18582.80',
#   'CLOSE': '18593.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '02 Jun 2023',
#   'OPEN': '18550.85',
#   'HIGH': '18573.70',
#   'LOW': '18478.40',
#   'CLOSE': '18534.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '01 Jun 2023',
#   'OPEN': '18579.40',
#   'HIGH': '18580.30',
#   'LOW': '18464.55',
#   'CLOSE': '18487.75'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '31 May 2023',
#   'OPEN': '18594.20',
#   'HIGH': '18603.90',
#   'LOW': '18483.85',
#   'CLOSE': '18534.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '30 May 2023',
#   'OPEN': '18606.65',
#   'HIGH': '18662.45',
#   'LOW': '18575.50',
#   'CLOSE': '18633.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '29 May 2023',
#   'OPEN': '18619.15',
#   'HIGH': '18641.20',
#   'LOW': '18581.25',
#   'CLOSE': '18598.65'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '26 May 2023',
#   'OPEN': '18368.35',
#   'HIGH': '18508.55',
#   'LOW': '18333.15',
#   'CLOSE': '18499.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '25 May 2023',
#   'OPEN': '18268.90',
#   'HIGH': '18338.10',
#   'LOW': '18202.40',
#   'CLOSE': '18321.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '24 May 2023',
#   'OPEN': '18294.80',
#   'HIGH': '18392.60',
#   'LOW': '18262.95',
#   'CLOSE': '18285.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '23 May 2023',
#   'OPEN': '18362.90',
#   'HIGH': '18419.75',
#   'LOW': '18324.20',
#   'CLOSE': '18348.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '22 May 2023',
#   'OPEN': '18201.10',
#   'HIGH': '18335.25',
#   'LOW': '18178.85',
#   'CLOSE': '18314.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '19 May 2023',
#   'OPEN': '18186.15',
#   'HIGH': '18218.10',
#   'LOW': '18060.40',
#   'CLOSE': '18203.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '18 May 2023',
#   'OPEN': '18287.50',
#   'HIGH': '18297.20',
#   'LOW': '18104.85',
#   'CLOSE': '18129.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '17 May 2023',
#   'OPEN': '18300.45',
#   'HIGH': '18309.00',
#   'LOW': '18115.35',
#   'CLOSE': '18181.75'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '16 May 2023',
#   'OPEN': '18432.35',
#   'HIGH': '18432.35',
#   'LOW': '18264.35',
#   'CLOSE': '18286.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '15 May 2023',
#   'OPEN': '18339.30',
#   'HIGH': '18458.90',
#   'LOW': '18287.90',
#   'CLOSE': '18398.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '12 May 2023',
#   'OPEN': '18273.75',
#   'HIGH': '18342.75',
#   'LOW': '18194.55',
#   'CLOSE': '18314.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '11 May 2023',
#   'OPEN': '18357.80',
#   'HIGH': '18389.70',
#   'LOW': '18270.40',
#   'CLOSE': '18297.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 May 2023',
#   'OPEN': '18313.60',
#   'HIGH': '18326.75',
#   'LOW': '18211.95',
#   'CLOSE': '18315.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 May 2023',
#   'OPEN': '18303.40',
#   'HIGH': '18344.20',
#   'LOW': '18229.65',
#   'CLOSE': '18265.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '08 May 2023',
#   'OPEN': '18120.60',
#   'HIGH': '18286.95',
#   'LOW': '18100.30',
#   'CLOSE': '18264.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '05 May 2023',
#   'OPEN': '18117.30',
#   'HIGH': '18216.95',
#   'LOW': '18055.45',
#   'CLOSE': '18069.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '04 May 2023',
#   'OPEN': '18081.00',
#   'HIGH': '18267.45',
#   'LOW': '18066.70',
#   'CLOSE': '18255.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '03 May 2023',
#   'OPEN': '18113.80',
#   'HIGH': '18116.35',
#   'LOW': '18042.40',
#   'CLOSE': '18089.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '02 May 2023',
#   'OPEN': '18124.80',
#   'HIGH': '18180.25',
#   'LOW': '18101.75',
#   'CLOSE': '18147.65'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '28 Apr 2023',
#   'OPEN': '17950.40',
#   'HIGH': '18089.15',
#   'LOW': '17885.30',
#   'CLOSE': '18065.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '27 Apr 2023',
#   'OPEN': '17813.10',
#   'HIGH': '17931.60',
#   'LOW': '17797.90',
#   'CLOSE': '17915.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '26 Apr 2023',
#   'OPEN': '17767.30',
#   'HIGH': '17827.75',
#   'LOW': '17711.20',
#   'CLOSE': '17813.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '25 Apr 2023',
#   'OPEN': '17761.55',
#   'HIGH': '17807.45',
#   'LOW': '17716.85',
#   'CLOSE': '17769.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '24 Apr 2023',
#   'OPEN': '17707.55',
#   'HIGH': '17754.50',
#   'LOW': '17612.50',
#   'CLOSE': '17743.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Apr 2023',
#   'OPEN': '17639.75',
#   'HIGH': '17663.20',
#   'LOW': '17553.95',
#   'CLOSE': '17624.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '20 Apr 2023',
#   'OPEN': '17638.60',
#   'HIGH': '17684.45',
#   'LOW': '17584.35',
#   'CLOSE': '17624.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '19 Apr 2023',
#   'OPEN': '17653.35',
#   'HIGH': '17666.15',
#   'LOW': '17579.85',
#   'CLOSE': '17618.75'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '18 Apr 2023',
#   'OPEN': '17766.60',
#   'HIGH': '17766.60',
#   'LOW': '17610.20',
#   'CLOSE': '17660.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '17 Apr 2023',
#   'OPEN': '17863.00',
#   'HIGH': '17863.00',
#   'LOW': '17574.05',
#   'CLOSE': '17706.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '13 Apr 2023',
#   'OPEN': '17807.30',
#   'HIGH': '17842.15',
#   'LOW': '17729.65',
#   'CLOSE': '17828.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '12 Apr 2023',
#   'OPEN': '17759.55',
#   'HIGH': '17825.75',
#   'LOW': '17717.25',
#   'CLOSE': '17812.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '11 Apr 2023',
#   'OPEN': '17704.80',
#   'HIGH': '17748.75',
#   'LOW': '17655.15',
#   'CLOSE': '17722.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 Apr 2023',
#   'OPEN': '17634.90',
#   'HIGH': '17694.10',
#   'LOW': '17597.95',
#   'CLOSE': '17624.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '06 Apr 2023',
#   'OPEN': '17533.85',
#   'HIGH': '17638.70',
#   'LOW': '17502.85',
#   'CLOSE': '17599.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '05 Apr 2023',
#   'OPEN': '17422.30',
#   'HIGH': '17570.55',
#   'LOW': '17402.70',
#   'CLOSE': '17557.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '03 Apr 2023',
#   'OPEN': '17427.95',
#   'HIGH': '17428.05',
#   'LOW': '17312.75',
#   'CLOSE': '17398.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '31 Mar 2023',
#   'OPEN': '17210.35',
#   'HIGH': '17381.60',
#   'LOW': '17204.65',
#   'CLOSE': '17359.75'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '29 Mar 2023',
#   'OPEN': '16977.30',
#   'HIGH': '17126.15',
#   'LOW': '16940.60',
#   'CLOSE': '17080.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '28 Mar 2023',
#   'OPEN': '17031.75',
#   'HIGH': '17061.75',
#   'LOW': '16913.75',
#   'CLOSE': '16951.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '27 Mar 2023',
#   'OPEN': '16984.30',
#   'HIGH': '17091.00',
#   'LOW': '16918.55',
#   'CLOSE': '16985.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '24 Mar 2023',
#   'OPEN': '17076.20',
#   'HIGH': '17109.45',
#   'LOW': '16917.35',
#   'CLOSE': '16945.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '23 Mar 2023',
#   'OPEN': '17097.40',
#   'HIGH': '17205.40',
#   'LOW': '17045.30',
#   'CLOSE': '17076.90'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '22 Mar 2023',
#   'OPEN': '17177.45',
#   'HIGH': '17207.25',
#   'LOW': '17107.85',
#   'CLOSE': '17151.90'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Mar 2023',
#   'OPEN': '17060.40',
#   'HIGH': '17127.70',
#   'LOW': '17016.00',
#   'CLOSE': '17107.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '20 Mar 2023',
#   'OPEN': '17066.60',
#   'HIGH': '17066.60',
#   'LOW': '16828.35',
#   'CLOSE': '16988.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '17 Mar 2023',
#   'OPEN': '17111.80',
#   'HIGH': '17145.80',
#   'LOW': '16958.15',
#   'CLOSE': '17100.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '16 Mar 2023',
#   'OPEN': '16994.65',
#   'HIGH': '17062.45',
#   'LOW': '16850.15',
#   'CLOSE': '16985.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '15 Mar 2023',
#   'OPEN': '17166.45',
#   'HIGH': '17211.35',
#   'LOW': '16938.90',
#   'CLOSE': '16972.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '14 Mar 2023',
#   'OPEN': '17160.55',
#   'HIGH': '17224.65',
#   'LOW': '16987.10',
#   'CLOSE': '17043.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '13 Mar 2023',
#   'OPEN': '17421.90',
#   'HIGH': '17529.90',
#   'LOW': '17113.45',
#   'CLOSE': '17154.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 Mar 2023',
#   'OPEN': '17443.80',
#   'HIGH': '17451.50',
#   'LOW': '17324.35',
#   'CLOSE': '17412.90'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Mar 2023',
#   'OPEN': '17772.05',
#   'HIGH': '17772.35',
#   'LOW': '17573.60',
#   'CLOSE': '17589.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '08 Mar 2023',
#   'OPEN': '17665.75',
#   'HIGH': '17766.50',
#   'LOW': '17602.25',
#   'CLOSE': '17754.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '06 Mar 2023',
#   'OPEN': '17680.35',
#   'HIGH': '17799.95',
#   'LOW': '17671.95',
#   'CLOSE': '17711.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '03 Mar 2023',
#   'OPEN': '17451.25',
#   'HIGH': '17644.75',
#   'LOW': '17427.70',
#   'CLOSE': '17594.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '02 Mar 2023',
#   'OPEN': '17421.50',
#   'HIGH': '17445.80',
#   'LOW': '17306.00',
#   'CLOSE': '17321.90'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '01 Mar 2023',
#   'OPEN': '17360.10',
#   'HIGH': '17467.75',
#   'LOW': '17345.25',
#   'CLOSE': '17450.90'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '28 Feb 2023',
#   'OPEN': '17383.25',
#   'HIGH': '17440.45',
#   'LOW': '17255.20',
#   'CLOSE': '17303.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '27 Feb 2023',
#   'OPEN': '17428.60',
#   'HIGH': '17451.60',
#   'LOW': '17299.00',
#   'CLOSE': '17392.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '24 Feb 2023',
#   'OPEN': '17591.35',
#   'HIGH': '17599.75',
#   'LOW': '17421.80',
#   'CLOSE': '17465.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '23 Feb 2023',
#   'OPEN': '17574.65',
#   'HIGH': '17620.05',
#   'LOW': '17455.40',
#   'CLOSE': '17511.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '22 Feb 2023',
#   'OPEN': '17755.35',
#   'HIGH': '17772.50',
#   'LOW': '17529.45',
#   'CLOSE': '17554.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Feb 2023',
#   'OPEN': '17905.80',
#   'HIGH': '17924.90',
#   'LOW': '17800.30',
#   'CLOSE': '17826.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '20 Feb 2023',
#   'OPEN': '17965.55',
#   'HIGH': '18004.35',
#   'LOW': '17818.40',
#   'CLOSE': '17844.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '17 Feb 2023',
#   'OPEN': '17974.85',
#   'HIGH': '18034.25',
#   'LOW': '17884.60',
#   'CLOSE': '17944.20'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '16 Feb 2023',
#   'OPEN': '18094.75',
#   'HIGH': '18134.75',
#   'LOW': '18000.65',
#   'CLOSE': '18035.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '15 Feb 2023',
#   'OPEN': '17896.60',
#   'HIGH': '18034.10',
#   'LOW': '17853.80',
#   'CLOSE': '18015.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '14 Feb 2023',
#   'OPEN': '17840.35',
#   'HIGH': '17954.55',
#   'LOW': '17800.05',
#   'CLOSE': '17929.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '13 Feb 2023',
#   'OPEN': '17859.10',
#   'HIGH': '17880.70',
#   'LOW': '17719.75',
#   'CLOSE': '17770.90'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 Feb 2023',
#   'OPEN': '17847.55',
#   'HIGH': '17876.95',
#   'LOW': '17801.00',
#   'CLOSE': '17856.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Feb 2023',
#   'OPEN': '17885.50',
#   'HIGH': '17916.90',
#   'LOW': '17779.80',
#   'CLOSE': '17893.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '08 Feb 2023',
#   'OPEN': '17750.30',
#   'HIGH': '17898.70',
#   'LOW': '17744.15',
#   'CLOSE': '17871.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '07 Feb 2023',
#   'OPEN': '17790.10',
#   'HIGH': '17811.15',
#   'LOW': '17652.55',
#   'CLOSE': '17721.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '06 Feb 2023',
#   'OPEN': '17818.55',
#   'HIGH': '17823.70',
#   'LOW': '17698.35',
#   'CLOSE': '17764.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '03 Feb 2023',
#   'OPEN': '17721.75',
#   'HIGH': '17870.30',
#   'LOW': '17584.20',
#   'CLOSE': '17854.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '02 Feb 2023',
#   'OPEN': '17517.10',
#   'HIGH': '17653.90',
#   'LOW': '17445.95',
#   'CLOSE': '17610.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '01 Feb 2023',
#   'OPEN': '17811.60',
#   'HIGH': '17972.20',
#   'LOW': '17353.40',
#   'CLOSE': '17616.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '31 Jan 2023',
#   'OPEN': '17731.45',
#   'HIGH': '17735.70',
#   'LOW': '17537.55',
#   'CLOSE': '17662.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '30 Jan 2023',
#   'OPEN': '17541.95',
#   'HIGH': '17709.15',
#   'LOW': '17405.55',
#   'CLOSE': '17648.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '27 Jan 2023',
#   'OPEN': '17877.20',
#   'HIGH': '17884.75',
#   'LOW': '17493.55',
#   'CLOSE': '17604.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '25 Jan 2023',
#   'OPEN': '18093.35',
#   'HIGH': '18100.60',
#   'LOW': '17846.15',
#   'CLOSE': '17891.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '24 Jan 2023',
#   'OPEN': '18183.95',
#   'HIGH': '18201.25',
#   'LOW': '18078.65',
#   'CLOSE': '18118.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '23 Jan 2023',
#   'OPEN': '18118.45',
#   'HIGH': '18162.60',
#   'LOW': '18063.45',
#   'CLOSE': '18118.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '20 Jan 2023',
#   'OPEN': '18115.60',
#   'HIGH': '18145.45',
#   'LOW': '18016.20',
#   'CLOSE': '18027.65'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '19 Jan 2023',
#   'OPEN': '18119.80',
#   'HIGH': '18155.20',
#   'LOW': '18063.75',
#   'CLOSE': '18107.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '18 Jan 2023',
#   'OPEN': '18074.30',
#   'HIGH': '18183.75',
#   'LOW': '18032.45',
#   'CLOSE': '18165.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '17 Jan 2023',
#   'OPEN': '17922.80',
#   'HIGH': '18072.05',
#   'LOW': '17886.95',
#   'CLOSE': '18053.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '16 Jan 2023',
#   'OPEN': '18033.15',
#   'HIGH': '18049.65',
#   'LOW': '17853.65',
#   'CLOSE': '17894.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '13 Jan 2023',
#   'OPEN': '17867.50',
#   'HIGH': '17999.35',
#   'LOW': '17774.25',
#   'CLOSE': '17956.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '12 Jan 2023',
#   'OPEN': '17920.85',
#   'HIGH': '17945.80',
#   'LOW': '17761.65',
#   'CLOSE': '17858.20'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '11 Jan 2023',
#   'OPEN': '17924.25',
#   'HIGH': '17976.35',
#   'LOW': '17824.35',
#   'CLOSE': '17895.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 Jan 2023',
#   'OPEN': '18121.30',
#   'HIGH': '18127.60',
#   'LOW': '17856.00',
#   'CLOSE': '17914.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Jan 2023',
#   'OPEN': '17952.55',
#   'HIGH': '18141.40',
#   'LOW': '17936.15',
#   'CLOSE': '18101.20'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '06 Jan 2023',
#   'OPEN': '18008.05',
#   'HIGH': '18047.40',
#   'LOW': '17795.55',
#   'CLOSE': '17859.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '05 Jan 2023',
#   'OPEN': '18101.95',
#   'HIGH': '18120.30',
#   'LOW': '17892.60',
#   'CLOSE': '17992.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '04 Jan 2023',
#   'OPEN': '18230.65',
#   'HIGH': '18243.00',
#   'LOW': '18020.60',
#   'CLOSE': '18042.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '03 Jan 2023',
#   'OPEN': '18163.20',
#   'HIGH': '18251.95',
#   'LOW': '18149.80',
#   'CLOSE': '18232.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '02 Jan 2023',
#   'OPEN': '18131.70',
#   'HIGH': '18215.15',
#   'LOW': '18086.50',
#   'CLOSE': '18197.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '30 Dec 2022',
#   'OPEN': '18259.10',
#   'HIGH': '18265.25',
#   'LOW': '18080.30',
#   'CLOSE': '18105.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '29 Dec 2022',
#   'OPEN': '18045.70',
#   'HIGH': '18229.70',
#   'LOW': '17992.80',
#   'CLOSE': '18191.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '28 Dec 2022',
#   'OPEN': '18084.75',
#   'HIGH': '18173.10',
#   'LOW': '18068.35',
#   'CLOSE': '18122.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '27 Dec 2022',
#   'OPEN': '18089.80',
#   'HIGH': '18149.25',
#   'LOW': '17967.45',
#   'CLOSE': '18132.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '26 Dec 2022',
#   'OPEN': '17830.40',
#   'HIGH': '18084.10',
#   'LOW': '17774.25',
#   'CLOSE': '18014.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '23 Dec 2022',
#   'OPEN': '17977.65',
#   'HIGH': '18050.45',
#   'LOW': '17779.50',
#   'CLOSE': '17806.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '22 Dec 2022',
#   'OPEN': '18288.80',
#   'HIGH': '18318.75',
#   'LOW': '18068.60',
#   'CLOSE': '18127.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Dec 2022',
#   'OPEN': '18435.15',
#   'HIGH': '18473.35',
#   'LOW': '18162.75',
#   'CLOSE': '18199.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '20 Dec 2022',
#   'OPEN': '18340.30',
#   'HIGH': '18404.90',
#   'LOW': '18202.65',
#   'CLOSE': '18385.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '19 Dec 2022',
#   'OPEN': '18288.10',
#   'HIGH': '18431.65',
#   'LOW': '18244.55',
#   'CLOSE': '18420.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '16 Dec 2022',
#   'OPEN': '18319.10',
#   'HIGH': '18440.95',
#   'LOW': '18255.15',
#   'CLOSE': '18269.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '15 Dec 2022',
#   'OPEN': '18614.40',
#   'HIGH': '18652.90',
#   'LOW': '18387.70',
#   'CLOSE': '18414.90'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '14 Dec 2022',
#   'OPEN': '18671.25',
#   'HIGH': '18696.10',
#   'LOW': '18632.90',
#   'CLOSE': '18660.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '13 Dec 2022',
#   'OPEN': '18524.40',
#   'HIGH': '18617.25',
#   'LOW': '18490.20',
#   'CLOSE': '18608.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '12 Dec 2022',
#   'OPEN': '18402.15',
#   'HIGH': '18521.55',
#   'LOW': '18345.70',
#   'CLOSE': '18497.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Dec 2022',
#   'OPEN': '18662.40',
#   'HIGH': '18664.70',
#   'LOW': '18410.10',
#   'CLOSE': '18496.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '08 Dec 2022',
#   'OPEN': '18570.85',
#   'HIGH': '18625.00',
#   'LOW': '18536.95',
#   'CLOSE': '18609.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '07 Dec 2022',
#   'OPEN': '18638.85',
#   'HIGH': '18668.30',
#   'LOW': '18528.40',
#   'CLOSE': '18560.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '06 Dec 2022',
#   'OPEN': '18600.65',
#   'HIGH': '18654.90',
#   'LOW': '18577.90',
#   'CLOSE': '18642.75'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '05 Dec 2022',
#   'OPEN': '18719.55',
#   'HIGH': '18728.60',
#   'LOW': '18591.35',
#   'CLOSE': '18701.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '02 Dec 2022',
#   'OPEN': '18752.40',
#   'HIGH': '18781.95',
#   'LOW': '18639.20',
#   'CLOSE': '18696.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '01 Dec 2022',
#   'OPEN': '18871.95',
#   'HIGH': '18887.60',
#   'LOW': '18778.20',
#   'CLOSE': '18812.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '11 Aug 2023',
#   'OPEN': '19554.25',
#   'HIGH': '19557.75',
#   'LOW': '19412.75',
#   'CLOSE': '19428.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 Aug 2023',
#   'OPEN': '19605.55',
#   'HIGH': '19623.60',
#   'LOW': '19495.40',
#   'CLOSE': '19543.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Aug 2023',
#   'OPEN': '19578.80',
#   'HIGH': '19645.50',
#   'LOW': '19467.50',
#   'CLOSE': '19632.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '08 Aug 2023',
#   'OPEN': '19627.20',
#   'HIGH': '19634.40',
#   'LOW': '19533.10',
#   'CLOSE': '19570.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '07 Aug 2023',
#   'OPEN': '19576.85',
#   'HIGH': '19620.45',
#   'LOW': '19524.80',
#   'CLOSE': '19597.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '04 Aug 2023',
#   'OPEN': '19462.80',
#   'HIGH': '19538.85',
#   'LOW': '19436.45',
#   'CLOSE': '19517.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '03 Aug 2023',
#   'OPEN': '19463.75',
#   'HIGH': '19537.65',
#   'LOW': '19296.45',
#   'CLOSE': '19381.65'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '02 Aug 2023',
#   'OPEN': '19655.40',
#   'HIGH': '19678.25',
#   'LOW': '19423.55',
#   'CLOSE': '19526.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '01 Aug 2023',
#   'OPEN': '19784.00',
#   'HIGH': '19795.60',
#   'LOW': '19704.60',
#   'CLOSE': '19733.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '30 Nov 2022',
#   'OPEN': '18625.70',
#   'HIGH': '18816.05',
#   'LOW': '18616.55',
#   'CLOSE': '18758.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '29 Nov 2022',
#   'OPEN': '18552.45',
#   'HIGH': '18678.10',
#   'LOW': '18552.15',
#   'CLOSE': '18618.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '28 Nov 2022',
#   'OPEN': '18430.55',
#   'HIGH': '18614.25',
#   'LOW': '18365.60',
#   'CLOSE': '18562.75'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '25 Nov 2022',
#   'OPEN': '18528.45',
#   'HIGH': '18534.90',
#   'LOW': '18445.10',
#   'CLOSE': '18512.75'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '24 Nov 2022',
#   'OPEN': '18326.10',
#   'HIGH': '18529.70',
#   'LOW': '18294.25',
#   'CLOSE': '18484.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '23 Nov 2022',
#   'OPEN': '18325.20',
#   'HIGH': '18325.40',
#   'LOW': '18246.00',
#   'CLOSE': '18267.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '22 Nov 2022',
#   'OPEN': '18179.15',
#   'HIGH': '18261.85',
#   'LOW': '18137.70',
#   'CLOSE': '18244.20'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Nov 2022',
#   'OPEN': '18246.40',
#   'HIGH': '18262.30',
#   'LOW': '18133.35',
#   'CLOSE': '18159.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '18 Nov 2022',
#   'OPEN': '18382.95',
#   'HIGH': '18394.60',
#   'LOW': '18209.80',
#   'CLOSE': '18307.65'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '17 Nov 2022',
#   'OPEN': '18358.70',
#   'HIGH': '18417.60',
#   'LOW': '18312.95',
#   'CLOSE': '18343.90'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '16 Nov 2022',
#   'OPEN': '18398.25',
#   'HIGH': '18442.15',
#   'LOW': '18344.15',
#   'CLOSE': '18409.65'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '15 Nov 2022',
#   'OPEN': '18362.75',
#   'HIGH': '18427.95',
#   'LOW': '18282.00',
#   'CLOSE': '18403.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '14 Nov 2022',
#   'OPEN': '18376.40',
#   'HIGH': '18399.45',
#   'LOW': '18311.40',
#   'CLOSE': '18329.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '11 Nov 2022',
#   'OPEN': '18272.35',
#   'HIGH': '18362.30',
#   'LOW': '18259.35',
#   'CLOSE': '18349.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 Nov 2022',
#   'OPEN': '18044.35',
#   'HIGH': '18103.10',
#   'LOW': '17969.40',
#   'CLOSE': '18028.20'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Nov 2022',
#   'OPEN': '18288.25',
#   'HIGH': '18296.40',
#   'LOW': '18117.50',
#   'CLOSE': '18157.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '07 Nov 2022',
#   'OPEN': '18211.75',
#   'HIGH': '18255.50',
#   'LOW': '18064.75',
#   'CLOSE': '18202.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '04 Nov 2022',
#   'OPEN': '18053.40',
#   'HIGH': '18135.10',
#   'LOW': '18017.15',
#   'CLOSE': '18117.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '03 Nov 2022',
#   'OPEN': '17968.35',
#   'HIGH': '18106.30',
#   'LOW': '17959.20',
#   'CLOSE': '18052.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'Nifty 50',
#   'HistoricalDate': '02 Nov 2022',
#   'OPEN': '18177.9',
#   'HIGH': '18178.75',
#   'LOW': '18048.65',
#   'CLOSE': '18082.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'Nifty 50',
#   'HistoricalDate': '01 Nov 2022',
#   'OPEN': '18130.7',
#   'HIGH': '18175.8',
#   'LOW': '18060.15',
#   'CLOSE': '18145.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '31 Oct 2022',
#   'OPEN': '17910.20',
#   'HIGH': '18022.80',
#   'LOW': '17899.90',
#   'CLOSE': '18012.20'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '28 Oct 2022',
#   'OPEN': '17756.40',
#   'HIGH': '17838.90',
#   'LOW': '17723.70',
#   'CLOSE': '17786.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '27 Oct 2022',
#   'OPEN': '17771.40',
#   'HIGH': '17783.90',
#   'LOW': '17654.50',
#   'CLOSE': '17736.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '25 Oct 2022',
#   'OPEN': '17808.30',
#   'HIGH': '17811.50',
#   'LOW': '17637.00',
#   'CLOSE': '17656.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '24 Oct 2022',
#   'OPEN': '17736.35',
#   'HIGH': '17777.55',
#   'LOW': '17707.40',
#   'CLOSE': '17730.75'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Oct 2022',
#   'OPEN': '17622.85',
#   'HIGH': '17670.15',
#   'LOW': '17520.75',
#   'CLOSE': '17576.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '20 Oct 2022',
#   'OPEN': '17423.10',
#   'HIGH': '17584.15',
#   'LOW': '17421.00',
#   'CLOSE': '17563.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '19 Oct 2022',
#   'OPEN': '17568.15',
#   'HIGH': '17607.60',
#   'LOW': '17472.85',
#   'CLOSE': '17512.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '18 Oct 2022',
#   'OPEN': '17438.75',
#   'HIGH': '17527.80',
#   'LOW': '17434.05',
#   'CLOSE': '17486.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '17 Oct 2022',
#   'OPEN': '17144.80',
#   'HIGH': '17328.55',
#   'LOW': '17098.55',
#   'CLOSE': '17311.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '14 Oct 2022',
#   'OPEN': '17322.30',
#   'HIGH': '17348.55',
#   'LOW': '17169.75',
#   'CLOSE': '17185.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '13 Oct 2022',
#   'OPEN': '17087.35',
#   'HIGH': '17112.35',
#   'LOW': '16956.95',
#   'CLOSE': '17014.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '12 Oct 2022',
#   'OPEN': '17025.55',
#   'HIGH': '17142.35',
#   'LOW': '16960.05',
#   'CLOSE': '17123.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '11 Oct 2022',
#   'OPEN': '17256.05',
#   'HIGH': '17261.80',
#   'LOW': '16950.30',
#   'CLOSE': '16983.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 Oct 2022',
#   'OPEN': '17094.35',
#   'HIGH': '17280.15',
#   'LOW': '17064.70',
#   'CLOSE': '17241.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '07 Oct 2022',
#   'OPEN': '17287.20',
#   'HIGH': '17337.35',
#   'LOW': '17216.95',
#   'CLOSE': '17314.65'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '06 Oct 2022',
#   'OPEN': '17379.25',
#   'HIGH': '17428.80',
#   'LOW': '17315.65',
#   'CLOSE': '17331.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '04 Oct 2022',
#   'OPEN': '17147.45',
#   'HIGH': '17287.30',
#   'LOW': '17117.30',
#   'CLOSE': '17274.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'Nifty 50',
#   'HistoricalDate': '03 Oct 2022',
#   'OPEN': '17102.1',
#   'HIGH': '17114.65',
#   'LOW': '16855.55',
#   'CLOSE': '16887.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'Nifty 50',
#   'HistoricalDate': '30 Sep 2022',
#   'OPEN': '16798.05',
#   'HIGH': '17187.1',
# ...
#   'HistoricalDate': '22 Dec 2020',
#   'OPEN': '13373.65',
#   'HIGH': '13492.05',
#   'LOW': '13192.9',
#   'CLOSE': '13466.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Dec 2020',
#   'OPEN': '13741.9',
#   'HIGH': '13777.5',
#   'LOW': '13131.45',
#   'CLOSE': '13328.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '18 Dec 2020',
#   'OPEN': '13764.4',
#   'HIGH': '13772.85',
#   'LOW': '13658.6',
#   'CLOSE': '13760.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '17 Dec 2020',
#   'OPEN': '13713.55',
#   'HIGH': '13773.25',
#   'LOW': '13673.55',
#   'CLOSE': '13740.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '16 Dec 2020',
#   'OPEN': '13663.1',
#   'HIGH': '13692.35',
#   'LOW': '13606.45',
#   'CLOSE': '13682.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '15 Dec 2020',
#   'OPEN': '13547.2',
#   'HIGH': '13589.65',
#   'LOW': '13447.05',
#   'CLOSE': '13567.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '14 Dec 2020',
#   'OPEN': '13571.45',
#   'HIGH': '13597.5',
#   'LOW': '13472.45',
#   'CLOSE': '13558.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '11 Dec 2020',
#   'OPEN': '13512.3',
#   'HIGH': '13579.35',
#   'LOW': '13402.85',
#   'CLOSE': '13513.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 Dec 2020',
#   'OPEN': '13488.5',
#   'HIGH': '13503.55',
#   'LOW': '13399.3',
#   'CLOSE': '13478.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Dec 2020',
#   'OPEN': '13458.1',
#   'HIGH': '13548.9',
#   'LOW': '13449.6',
#   'CLOSE': '13529.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '08 Dec 2020',
#   'OPEN': '13393.85',
#   'HIGH': '13435.45',
#   'LOW': '13311.05',
#   'CLOSE': '13392.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '07 Dec 2020',
#   'OPEN': '13264.85',
#   'HIGH': '13366.65',
#   'LOW': '13241.95',
#   'CLOSE': '13355.75'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '04 Dec 2020',
#   'OPEN': '13177.4',
#   'HIGH': '13280.05',
#   'LOW': '13152.85',
#   'CLOSE': '13258.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '03 Dec 2020',
#   'OPEN': '13215.3',
#   'HIGH': '13216.6',
#   'LOW': '13107.9',
#   'CLOSE': '13133.90'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '02 Dec 2020',
#   'OPEN': '13121.4',
#   'HIGH': '13128.5',
#   'LOW': '12983.55',
#   'CLOSE': '13113.75'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '01 Dec 2020',
#   'OPEN': '13062.2',
#   'HIGH': '13128.4',
#   'LOW': '12962.8',
#   'CLOSE': '13109.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '27 Nov 2020',
#   'OPEN': '13012.05',
#   'HIGH': '13035.3',
#   'LOW': '12914.3',
#   'CLOSE': '12968.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '26 Nov 2020',
#   'OPEN': '12906.45',
#   'HIGH': '13018',
#   'LOW': '12790.4',
#   'CLOSE': '12987.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '25 Nov 2020',
#   'OPEN': '13130',
#   'HIGH': '13145.85',
#   'LOW': '12833.65',
#   'CLOSE': '12858.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '24 Nov 2020',
#   'OPEN': '13002.6',
#   'HIGH': '13079.1',
#   'LOW': '12978',
#   'CLOSE': '13055.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '23 Nov 2020',
#   'OPEN': '12960.3',
#   'HIGH': '12968.85',
#   'LOW': '12825.7',
#   'CLOSE': '12926.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '20 Nov 2020',
#   'OPEN': '12813.4',
#   'HIGH': '12892.45',
#   'LOW': '12730.25',
#   'CLOSE': '12859.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '19 Nov 2020',
#   'OPEN': '12839.5',
#   'HIGH': '12963',
#   'LOW': '12745.75',
#   'CLOSE': '12771.70'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '18 Nov 2020',
#   'OPEN': '12860.1',
#   'HIGH': '12948.85',
#   'LOW': '12819.35',
#   'CLOSE': '12938.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '17 Nov 2020',
#   'OPEN': '12932.5',
#   'HIGH': '12934.05',
#   'LOW': '12797.1',
#   'CLOSE': '12874.20'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '14 Nov 2020',
#   'OPEN': '12823.35',
#   'HIGH': '12828.7',
#   'LOW': '12749.45',
#   'CLOSE': '12780.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '13 Nov 2020',
#   'OPEN': '12659.7',
#   'HIGH': '12735.95',
#   'LOW': '12607.7',
#   'CLOSE': '12719.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '12 Nov 2020',
#   'OPEN': '12702.15',
#   'HIGH': '12741.15',
#   'LOW': '12624.85',
#   'CLOSE': '12690.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '11 Nov 2020',
#   'OPEN': '12680.6',
#   'HIGH': '12769.75',
#   'LOW': '12571.1',
#   'CLOSE': '12749.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 Nov 2020',
#   'OPEN': '12556.4',
#   'HIGH': '12643.9',
#   'LOW': '12475.25',
#   'CLOSE': '12631.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Nov 2020',
#   'OPEN': '12399.4',
#   'HIGH': '12474.05',
#   'LOW': '12367.35',
#   'CLOSE': '12461.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '06 Nov 2020',
#   'OPEN': '12156.65',
#   'HIGH': '12280.4',
#   'LOW': '12131.85',
#   'CLOSE': '12263.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '05 Nov 2020',
#   'OPEN': '12062.4',
#   'HIGH': '12131.1',
#   'LOW': '12027.6',
#   'CLOSE': '12120.30'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '04 Nov 2020',
#   'OPEN': '11783.35',
#   'HIGH': '11929.65',
#   'LOW': '11756.4',
#   'CLOSE': '11908.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '03 Nov 2020',
#   'OPEN': '11734.45',
#   'HIGH': '11836.2',
#   'LOW': '11723.3',
#   'CLOSE': '11813.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '02 Nov 2020',
#   'OPEN': '11697.35',
#   'HIGH': '11725.65',
#   'LOW': '11557.4',
#   'CLOSE': '11669.15'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '30 Oct 2020',
#   'OPEN': '11678.45',
#   'HIGH': '11748.95',
#   'LOW': '11535.45',
#   'CLOSE': '11642.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '29 Oct 2020',
#   'OPEN': '11633.3',
#   'HIGH': '11744.15',
#   'LOW': '11606.45',
#   'CLOSE': '11670.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '28 Oct 2020',
#   'OPEN': '11922.6',
#   'HIGH': '11929.4',
#   'LOW': '11684.85',
#   'CLOSE': '11729.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '27 Oct 2020',
#   'OPEN': '11807.1',
#   'HIGH': '11899.05',
#   'LOW': '11723',
#   'CLOSE': '11889.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '26 Oct 2020',
#   'OPEN': '11937.4',
#   'HIGH': '11942.85',
#   'LOW': '11711.7',
#   'CLOSE': '11767.75'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '23 Oct 2020',
#   'OPEN': '11957.9',
#   'HIGH': '11974.55',
#   'LOW': '11908.75',
#   'CLOSE': '11930.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '22 Oct 2020',
#   'OPEN': '11890',
#   'HIGH': '11939.55',
#   'LOW': '11823.45',
#   'CLOSE': '11896.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Oct 2020',
#   'OPEN': '11958.55',
#   'HIGH': '12018.65',
#   'LOW': '11775.75',
#   'CLOSE': '11937.65'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '20 Oct 2020',
#   'OPEN': '11861',
#   'HIGH': '11949.25',
#   'LOW': '11837.25',
#   'CLOSE': '11896.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '19 Oct 2020',
#   'OPEN': '11879.2',
#   'HIGH': '11898.25',
#   'LOW': '11820.4',
#   'CLOSE': '11873.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '16 Oct 2020',
#   'OPEN': '11727.4',
#   'HIGH': '11789.75',
#   'LOW': '11667.85',
#   'CLOSE': '11762.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '15 Oct 2020',
#   'OPEN': '12023.45',
#   'HIGH': '12025.45',
#   'LOW': '11661.3',
#   'CLOSE': '11680.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '14 Oct 2020',
#   'OPEN': '11917.4',
#   'HIGH': '11997.2',
#   'LOW': '11822.15',
#   'CLOSE': '11971.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '13 Oct 2020',
#   'OPEN': '11934.65',
#   'HIGH': '11988.2',
#   'LOW': '11888.9',
#   'CLOSE': '11934.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '12 Oct 2020',
#   'OPEN': '11973.55',
#   'HIGH': '12022.05',
#   'LOW': '11867.2',
#   'CLOSE': '11930.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Oct 2020',
#   'OPEN': '11852.05',
#   'HIGH': '11938.6',
#   'LOW': '11805.2',
#   'CLOSE': '11914.20'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '08 Oct 2020',
#   'OPEN': '11835.4',
#   'HIGH': '11905.7',
#   'LOW': '11791.15',
#   'CLOSE': '11834.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '07 Oct 2020',
#   'OPEN': '11679.25',
#   'HIGH': '11763.05',
#   'LOW': '11629.35',
#   'CLOSE': '11738.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '06 Oct 2020',
#   'OPEN': '11603.45',
#   'HIGH': '11680.3',
#   'LOW': '11564.3',
#   'CLOSE': '11662.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '05 Oct 2020',
#   'OPEN': '11487.8',
#   'HIGH': '11578.05',
#   'LOW': '11452.3',
#   'CLOSE': '11503.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '01 Oct 2020',
#   'OPEN': '11364.45',
#   'HIGH': '11428.6',
#   'LOW': '11347.05',
#   'CLOSE': '11416.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '30 Sep 2020',
#   'OPEN': '11244.45',
#   'HIGH': '11295.4',
#   'LOW': '11184.55',
#   'CLOSE': '11247.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '29 Sep 2020',
#   'OPEN': '11288.6',
#   'HIGH': '11305.4',
#   'LOW': '11181',
#   'CLOSE': '11222.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '28 Sep 2020',
#   'OPEN': '11140.85',
#   'HIGH': '11239.35',
#   'LOW': '11099.85',
#   'CLOSE': '11227.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '25 Sep 2020',
#   'OPEN': '10910.4',
#   'HIGH': '11072.6',
#   'LOW': '10854.85',
#   'CLOSE': '11050.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '24 Sep 2020',
#   'OPEN': '11011',
#   'HIGH': '11015.3',
#   'LOW': '10790.2',
#   'CLOSE': '10805.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '23 Sep 2020',
#   'OPEN': '11258.75',
#   'HIGH': '11259.55',
#   'LOW': '11024.4',
#   'CLOSE': '11131.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '22 Sep 2020',
#   'OPEN': '11301.75',
#   'HIGH': '11302.2',
#   'LOW': '11084.65',
#   'CLOSE': '11153.65'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Sep 2020',
#   'OPEN': '11503.8',
#   'HIGH': '11535.25',
#   'LOW': '11218.5',
#   'CLOSE': '11250.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '18 Sep 2020',
#   'OPEN': '11584.1',
#   'HIGH': '11584.1',
#   'LOW': '11446.1',
#   'CLOSE': '11504.95'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '17 Sep 2020',
#   'OPEN': '11539.4',
#   'HIGH': '11587.2',
#   'LOW': '11498.5',
#   'CLOSE': '11516.10'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '16 Sep 2020',
#   'OPEN': '11538.45',
#   'HIGH': '11618.1',
#   'LOW': '11516.75',
#   'CLOSE': '11604.55'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '15 Sep 2020',
#   'OPEN': '11487.2',
#   'HIGH': '11535.95',
#   'LOW': '11442.25',
#   'CLOSE': '11521.80'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '14 Sep 2020',
#   'OPEN': '11540.15',
#   'HIGH': '11568.9',
#   'LOW': '11383.55',
#   'CLOSE': '11440.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '11 Sep 2020',
#   'OPEN': '11447.8',
#   'HIGH': '11493.5',
#   'LOW': '11419.9',
#   'CLOSE': '11464.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '10 Sep 2020',
#   'OPEN': '11363.3',
#   'HIGH': '11464.05',
#   'LOW': '11327.4',
#   'CLOSE': '11449.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '09 Sep 2020',
#   'OPEN': '11218.6',
#   'HIGH': '11298.15',
#   'LOW': '11185.15',
#   'CLOSE': '11278.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '08 Sep 2020',
#   'OPEN': '11378.55',
#   'HIGH': '11437.25',
#   'LOW': '11290.45',
#   'CLOSE': '11317.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '07 Sep 2020',
#   'OPEN': '11359.6',
#   'HIGH': '11381.15',
#   'LOW': '11251.7',
#   'CLOSE': '11355.05'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '04 Sep 2020',
#   'OPEN': '11354.4',
#   'HIGH': '11452.05',
#   'LOW': '11303.65',
#   'CLOSE': '11333.85'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '03 Sep 2020',
#   'OPEN': '11566.2',
#   'HIGH': '11584.95',
#   'LOW': '11507.65',
#   'CLOSE': '11527.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '02 Sep 2020',
#   'OPEN': '11478.55',
#   'HIGH': '11554.75',
#   'LOW': '11430.4',
#   'CLOSE': '11535.00'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '01 Sep 2020',
#   'OPEN': '11464.3',
#   'HIGH': '11553.55',
#   'LOW': '11366.9',
#   'CLOSE': '11470.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '31 Aug 2020',
#   'OPEN': '11777.55',
#   'HIGH': '11794.25',
#   'LOW': '11325.85',
#   'CLOSE': '11387.50'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '28 Aug 2020',
#   'OPEN': '11602.95',
#   'HIGH': '11686.05',
#   'LOW': '11589.4',
#   'CLOSE': '11647.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '27 Aug 2020',
#   'OPEN': '11609.3',
#   'HIGH': '11617.35',
#   'LOW': '11540.6',
#   'CLOSE': '11559.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '26 Aug 2020',
#   'OPEN': '11512.85',
#   'HIGH': '11561.75',
#   'LOW': '11461.85',
#   'CLOSE': '11549.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '25 Aug 2020',
#   'OPEN': '11513.1',
#   'HIGH': '11525.9',
#   'LOW': '11423.35',
#   'CLOSE': '11472.25'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '24 Aug 2020',
#   'OPEN': '11412',
#   'HIGH': '11497.25',
#   'LOW': '11410.65',
#   'CLOSE': '11466.45'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '21 Aug 2020',
#   'OPEN': '11409.65',
#   'HIGH': '11418.5',
#   'LOW': '11362.2',
#   'CLOSE': '11371.60'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '20 Aug 2020',
#   'OPEN': '11317.45',
#   'HIGH': '11361.45',
#   'LOW': '11289.8',
#   'CLOSE': '11312.20'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '19 Aug 2020',
#   'OPEN': '11452.15',
#   'HIGH': '11460.35',
#   'LOW': '11394.1',
#   'CLOSE': '11408.40'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '18 Aug 2020',
#   'OPEN': '11259.8',
#   'HIGH': '11401.7',
#   'LOW': '11253.15',
#   'CLOSE': '11385.35'},
#  {'Index Name': 'Nifty 50',
#   'INDEX_NAME': 'NIFTY 50',
#   'HistoricalDate': '17 Aug 2020',
#   'OPEN': '11248.9',
#   'HIGH': '11267.1',
#   'LOW': '11144.5',
#   'CLOSE': '11247.10'}]

# %% [markdown]
# #### 1.2.2. Converting into dataframe

# %%
def convert_to_date(date_str):
    date_obj = datetime.datetime.strptime(date_str, '%d %b %Y')
    return date_obj

nifty_index_historical_df = pd.DataFrame(raw_index_data)
nifty_index_historical_df['HistoricalDate'] = nifty_index_historical_df['HistoricalDate'].apply(convert_to_date)
nifty_index_historical_df = nifty_index_historical_df.sort_values('HistoricalDate').reset_index(drop=True)
nifty_index_historical_df
# Out:
#                       Index Name                   INDEX_NAME HistoricalDate  \
# 0                       Nifty 50                     NIFTY 50     2020-08-17
# 1                       Nifty 50                     NIFTY 50     2020-08-17
# 2                       Nifty 50                     NIFTY 50     2020-08-18
# 3                       Nifty 50                     NIFTY 50     2020-08-18
# 4                       Nifty 50                     NIFTY 50     2020-08-19
# ..                           ...                          ...            ...
# 801                     Nifty 50                     NIFTY 50     2023-08-11
# 802                     Nifty 50                     NIFTY 50     2023-08-11
# 803  Nifty Midcap150 Momentum 50  NIFTY MIDCAP150 MOMENTUM 50     2023-08-14
# 804                     Nifty 50                     NIFTY 50     2023-08-14
# 805                     Nifty 50                     NIFTY 50     2023-08-16
#
#          OPEN      HIGH       LOW     CLOSE
# 0     11248.9   11267.1   11144.5  11247.10
# 1     11248.9   11267.1   11144.5  11247.10
# 2     11259.8   11401.7  11253.15  11385.35
# 3     11259.8   11401.7  11253.15  11385.35
# 4    11452.15  11460.35   11394.1  11408.40
# ..        ...       ...       ...       ...
# 801  19554.25  19557.75  19412.75  19428.30
# 802  19554.25  19557.75  19412.75  19428.30
# 803         -         -         -  38545.35
# 804  19383.95  19465.85  19257.90  19434.55
# 805  19369.00  19482.75  19317.20  19465.00
#
# [806 rows x 7 columns]

# %% [markdown]
# #### 1.2.3. Doing data processing -- filtering and dropping duplicates

# %%
nifty_index_historical_df = nifty_index_historical_df.drop_duplicates()
nifty_index_historical_df = nifty_index_historical_df.loc[nifty_index_historical_df.loc[:, 'Index Name'] == 'Nifty 50']
nifty_index_historical_df
# Out:
#     Index Name INDEX_NAME HistoricalDate      OPEN      HIGH       LOW  \
# 0     Nifty 50   NIFTY 50     2020-08-17   11248.9   11267.1   11144.5
# 2     Nifty 50   NIFTY 50     2020-08-18   11259.8   11401.7  11253.15
# 4     Nifty 50   NIFTY 50     2020-08-19  11452.15  11460.35   11394.1
# 6     Nifty 50   NIFTY 50     2020-08-20  11317.45  11361.45   11289.8
# 8     Nifty 50   NIFTY 50     2020-08-21  11409.65   11418.5   11362.2
# ..         ...        ...            ...       ...       ...       ...
# 792   Nifty 50   NIFTY 50     2023-08-09  19578.80  19645.50  19467.50
# 795   Nifty 50   NIFTY 50     2023-08-10  19605.55  19623.60  19495.40
# 799   Nifty 50   NIFTY 50     2023-08-11  19554.25  19557.75  19412.75
# 804   Nifty 50   NIFTY 50     2023-08-14  19383.95  19465.85  19257.90
# 805   Nifty 50   NIFTY 50     2023-08-16  19369.00  19482.75  19317.20
#
#         CLOSE
# 0    11247.10
# 2    11385.35
# 4    11408.40
# 6    11312.20
# 8    11371.60
# ..        ...
# 792  19632.55
# 795  19543.10
# 799  19428.30
# 804  19434.55
# 805  19465.00
#
# [746 rows x 7 columns]

# %% [markdown]
# #### 1.2.4 Stitching it all together

# %%
import datetime
import pandas as pd
from dateutil.relativedelta import relativedelta
from jugaad_data.nse import index_raw

def convert_to_date(date_str):
    date_obj = datetime.datetime.strptime(date_str, '%d %b %Y')
    return date_obj

# Get from and to dates
to_date = datetime.date.today()
from_date = to_date - relativedelta(years=3)
print(from_date, to_date)

# Fetch the index data 
raw_index_data = index_raw(symbol="NIFTY 50", from_date=from_date, to_date=to_date)

# Converting into dataframe 
nifty_index_historical_df = pd.DataFrame(raw_index_data)
nifty_index_historical_df['HistoricalDate'] = nifty_index_historical_df['HistoricalDate'].apply(convert_to_date)
nifty_index_historical_df = nifty_index_historical_df.sort_values('HistoricalDate').reset_index(drop=True)
nifty_index_historical_df = nifty_index_historical_df.drop_duplicates()
nifty_index_historical_df = nifty_index_historical_df.loc[nifty_index_historical_df.loc[:, 'Index Name'] == 'Nifty 50']
nifty_index_historical_df
# Out:
# 2020-08-17 2023-08-17
#     Index Name INDEX_NAME HistoricalDate      OPEN      HIGH       LOW  \
# 0     Nifty 50   NIFTY 50     2020-08-17   11248.9   11267.1   11144.5
# 2     Nifty 50   NIFTY 50     2020-08-18   11259.8   11401.7  11253.15
# 4     Nifty 50   NIFTY 50     2020-08-19  11452.15  11460.35   11394.1
# 6     Nifty 50   NIFTY 50     2020-08-20  11317.45  11361.45   11289.8
# 8     Nifty 50   NIFTY 50     2020-08-21  11409.65   11418.5   11362.2
# ..         ...        ...            ...       ...       ...       ...
# 792   Nifty 50   NIFTY 50     2023-08-09  19578.80  19645.50  19467.50
# 795   Nifty 50   NIFTY 50     2023-08-10  19605.55  19623.60  19495.40
# 799   Nifty 50   NIFTY 50     2023-08-11  19554.25  19557.75  19412.75
# 804   Nifty 50   NIFTY 50     2023-08-14  19383.95  19465.85  19257.90
# 805   Nifty 50   NIFTY 50     2023-08-16  19369.00  19482.75  19317.20
#
#         CLOSE
# 0    11247.10
# 2    11385.35
# 4    11408.40
# 6    11312.20
# 8    11371.60
# ..        ...
# 792  19632.55
# 795  19543.10
# 799  19428.30
# 804  19434.55
# 805  19465.00
#
# [746 rows x 7 columns]

# %% [markdown]
# #### 1.2.5 Making the code more readable

# %%
import datetime
import pandas as pd
from dateutil.relativedelta import relativedelta
from jugaad_data.nse import index_raw

n_years = 3 # Parameter for historical years

def convert_to_date(date_str):
    date_obj = datetime.datetime.strptime(date_str, '%d %b %Y')
    return date_obj

# Get from and to dates
to_date = datetime.date.today()
from_date = to_date - relativedelta(years=n_years)
print(from_date, to_date)

# Fetch the index data 
raw_index_data = index_raw(symbol="NIFTY 50", from_date=from_date, to_date=to_date)

# Converting into dataframe and processing the data
nifty_historical_df = (pd.DataFrame(raw_index_data)\
                            .assign(HistoricalDate=lambda x: x['HistoricalDate'].apply(convert_to_date))\
                            .sort_values('HistoricalDate')\
                            .drop_duplicates()\
                            .loc[lambda x: x['Index Name'] == 'Nifty 50']\
                            .reset_index(drop=True))
nifty_historical_df
# Out:
# 2020-08-17 2023-08-17
#     Index Name INDEX_NAME HistoricalDate      OPEN      HIGH       LOW  \
# 0     Nifty 50   NIFTY 50     2020-08-17   11248.9   11267.1   11144.5
# 1     Nifty 50   NIFTY 50     2020-08-18   11259.8   11401.7  11253.15
# 2     Nifty 50   NIFTY 50     2020-08-19  11452.15  11460.35   11394.1
# 3     Nifty 50   NIFTY 50     2020-08-20  11317.45  11361.45   11289.8
# 4     Nifty 50   NIFTY 50     2020-08-21  11409.65   11418.5   11362.2
# ..         ...        ...            ...       ...       ...       ...
# 741   Nifty 50   NIFTY 50     2023-08-09  19578.80  19645.50  19467.50
# 742   Nifty 50   NIFTY 50     2023-08-10  19605.55  19623.60  19495.40
# 743   Nifty 50   NIFTY 50     2023-08-11  19554.25  19557.75  19412.75
# 744   Nifty 50   NIFTY 50     2023-08-14  19383.95  19465.85  19257.90
# 745   Nifty 50   NIFTY 50     2023-08-16  19369.00  19482.75  19317.20
#
#         CLOSE
# 0    11247.10
# 1    11385.35
# 2    11408.40
# 3    11312.20
# 4    11371.60
# ..        ...
# 741  19632.55
# 742  19543.10
# 743  19428.30
# 744  19434.55
# 745  19465.00
#
# [746 rows x 7 columns]

# %% [markdown]
# #### 1.2.6.  Plotting the nifty historical data and a trendline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

plt.figure(figsize=(12, 6))

nifty_historical_df['CLOSE'] = nifty_historical_df['CLOSE'].astype('float')

# Plot the historical Nifty data
plt.plot(nifty_historical_df['HistoricalDate'].values, nifty_historical_df['CLOSE'].values)

# Calculate and plot the trend line
x_values = np.arange(len(nifty_historical_df)).reshape(-1, 1)
y_values = nifty_historical_df['CLOSE'].values.reshape(-1, 1)
regressor = LinearRegression().fit(x_values, y_values)
trend_line = regressor.predict(x_values)
plt.plot(nifty_historical_df['HistoricalDate'].values, trend_line, linestyle='--', color='g', label='Trend Line')

# Set the title and labels
plt.title('Nifty Index')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. Stocks & ETFs

# %% [markdown]
# #### 2.1. Using `jugaad_data`

# %%
from jugaad_data.nse import NSELive
n = NSELive()
tata_motors_price, mon100_etf = n.stock_quote('TATAMOTORS')['priceInfo']['lastPrice'], n.stock_quote('MON100')['priceInfo']['lastPrice']
tata_motors_price, mon100_etf
# Out:
# (613.35, 120.4)

# %%
from jugaad_data.nse import stock_df
tata_motors_stock_df = stock_df(symbol='TATAMOTORS', 
                                from_date=date(2023,1,1), 
                                to_date=date(2023,1,5), 
                                series="EQ")
tata_motors_stock_df
# Out:
#         DATE SERIES    OPEN    HIGH     LOW  PREV. CLOSE     LTP   CLOSE  \
# 0 2023-01-05     EQ 387.900 388.750 382.500      385.600 387.000 386.900
# 1 2023-01-04     EQ 394.800 394.800 385.000      393.900 385.750 385.600
# 2 2023-01-03     EQ 396.000 398.350 393.000      394.800 393.900 393.900
# 3 2023-01-02     EQ 392.500 396.000 391.000      387.950 395.000 394.800
#
#      VWAP   52W H   52W L    VOLUME          VALUE  NO OF TRADES      SYMBOL
# 0 386.130 528.500 366.200  10443908 4032691650.750        130918  TATAMOTORS
# 1 387.300 528.500 366.200  16121049 6243666263.200        172074  TATAMOTORS
# 2 395.210 528.500 366.200   9431220 3727287418.500        133270  TATAMOTORS
# 3 394.170 528.500 366.200  10501357 4139354568.300        142685  TATAMOTORS

# %% [markdown]
# #### 2.2. Using `yfinance`

# %%
import yfinance as yf

# end date data is excluded 
stock_data = yf.download('TATAMOTORS.NS', start='2023-01-01', end='2023-01-06')
stock_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#               Open    High     Low   Close  Adj Close    Volume
# Date
# 2023-01-02 392.500 396.000 391.000 394.800    393.573  10501357
# 2023-01-03 396.000 398.350 393.000 393.900    392.676   9431220
# 2023-01-04 394.800 394.800 385.000 385.600    384.402  16121049
# 2023-01-05 387.900 388.750 382.500 386.900    385.698  10443908

# %%
info = yf.Ticker('TATAMOTORS.NS').info
info['sharesOutstanding'], info['floatShares'], info['currentPrice']
# Out:
# (3321860096, 2129548249, 613.75)

# %%
info
# Out:
# {'address1': 'Bombay House',
#  'address2': '24, Homi Mody Street',
#  'city': 'Mumbai',
#  'zip': '400001',
#  'country': 'India',
#  'phone': '91 22 6665 8282',
#  'fax': '91 22 6665 7799',
#  'website': 'https://www.tatamotors.com',
#  'industry': 'Auto Manufacturers',
#  'industryDisp': 'Auto Manufacturers',
#  'sector': 'Consumer Cyclical',
#  'sectorDisp': 'Consumer Cyclical',
#  'longBusinessSummary': 'Tata Motors Limited designs, develops, manufactures, and sells various automotive vehicles. The company offers passenger cars; sports utility vehicles; intermediate and light commercial vehicles; small, medium, and heavy commercial vehicles; defense vehicles; pickups, wingers, buses, and trucks; and electric vehicles, as well as related spare parts and accessories. It also manufactures engines for industrial and marine applications, and aggregates comprising axles and transmissions for commercial vehicles; and factory automation equipment, as well as provides information technology and vehicle financing services. The company offers its products under the Tata, Daewoo, Harrier, Safari, Fiat, Nexon, Altroz, Punch, Tiago, Tigor, Jaguar, and Land Rover brands. It operates in India, China, the United States, the United Kingdom, rest of Europe, and internationally. The company was incorporated in 1945 and is headquartered in Mumbai, India.',
#  'fullTimeEmployees': 81811,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Pathamadai Balachandran Balaji',
#    'age': 53,
#    'title': 'Group Chief Financial Officer',
#    'yearBorn': 1969,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Girish Arun Wagh',
#    'age': 52,
#    'title': 'Pres of Commercial Vehicles Bus. Unit & Exec. Director',
#    'yearBorn': 1970,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Petkar M. Rajendra',
#    'age': 55,
#    'title': 'CTO & Pres',
#    'yearBorn': 1967,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Ravindra Kumar Godabanal Parameswarappa',
#    'title': 'Pres & Chief HR Officer',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Rajesh  Kannan',
#    'title': 'Pres and Chief Digital & Information Officer',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Dhiman  Gupta',
#    'title': 'Head of Treasury, Investor Relations and M&A',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Maloy Kumar Gupta',
#    'age': 51,
#    'title': 'Compliance Officer & Company Sec.',
#    'yearBorn': 1971,
#    'fiscalYear': 2022,
#    'totalPay': 6873878,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Sudeep  Bhalla',
#    'title': 'Head of Corp. Communications',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Shubhranshu  Singh',
#    'title': 'VP of Marketing of Domestic & International business',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. R.  Ramakrishnan',
#    'age': 59,
#    'title': 'Global Head of Customer Care',
#    'yearBorn': 1963,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 5,
#  'boardRisk': 5,
#  'compensationRisk': 8,
#  'shareHolderRightsRisk': 8,
#  'overallRisk': 8,
#  'governanceEpochDate': 1690848000,
#  'compensationAsOfEpochDate': 1672444800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 618.75,
#  'open': 620.0,
#  'dayLow': 611.0,
#  'dayHigh': 622.0,
#  'regularMarketPreviousClose': 618.75,
#  'regularMarketOpen': 620.0,
#  'regularMarketDayLow': 611.0,
#  'regularMarketDayHigh': 622.0,
#  'dividendRate': 2.0,
#  'dividendYield': 0.0033000002,
#  'exDividendDate': 1690502400,
#  'payoutRatio': 0.0,
#  'beta': 1.879146,
#  'trailingPE': 97.575516,
#  'volume': 12116167,
#  'regularMarketVolume': 12116167,
#  'averageVolume': 12430551,
#  'averageVolume10days': 16322671,
#  'averageDailyVolume10Day': 16322671,
#  'bid': 0.0,
#  'ask': 0.0,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 2216300380160,
#  'fiftyTwoWeekLow': 375.2,
#  'fiftyTwoWeekHigh': 665.4,
#  'priceToSalesTrailing12Months': 0.58902115,
#  'fiftyDayAverage': 602.755,
#  'twoHundredDayAverage': 483.64926,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'currency': 'INR',
#  'enterpriseValue': 3261444390912,
#  'profitMargins': 0.02823,
#  'floatShares': 2129548249,
#  'sharesOutstanding': 3321860096,
#  'heldPercentInsiders': 0.48127997,
#  'heldPercentInstitutions': 0.23642999,
#  'impliedSharesOutstanding': 3589299968,
#  'bookValue': 118.338,
#  'priceToBook': 5.186415,
#  'lastFiscalYearEnd': 1680220800,
#  'nextFiscalYearEnd': 1711843200,
#  'mostRecentQuarter': 1688083200,
#  'netIncomeToCommon': 106236903424,
#  'trailingEps': 6.29,
#  'lastSplitFactor': '5:1',
#  'lastSplitDate': 1315785600,
#  'enterpriseToRevenue': 0.867,
#  'enterpriseToEbitda': 10.193,
#  '52WeekChange': 0.27629948,
#  'SandP52WeekChange': 0.028150678,
#  'lastDividendValue': 2.0,
#  'lastDividendDate': 1690502400,
#  'exchange': 'NSI',
#  'quoteType': 'EQUITY',
#  'symbol': 'TATAMOTORS.NS',
#  'underlyingSymbol': 'TATAMOTORS.NS',
#  'shortName': 'TATA MOTORS LTD.',
#  'longName': 'Tata Motors Limited',
#  'firstTradeDateEpochUtc': 819863100,
#  'timeZoneFullName': 'Asia/Kolkata',
#  'timeZoneShortName': 'IST',
#  'uuid': 'ddba5579-685b-35a6-8ca9-fdc0ae8f12f6',
#  'messageBoardId': 'finmb_874652',
#  'gmtOffSetMilliseconds': 19800000,
#  'currentPrice': 613.75,
#  'recommendationKey': 'none',
#  'totalCash': 550787809280,
#  'totalCashPerShare': 143.815,
#  'ebitda': 319972474880,
#  'totalDebt': 1371354562560,
#  'totalRevenue': 3762683904000,
#  'debtToEquity': 248.887,
#  'revenuePerShare': 982.463,
#  'revenueGrowth': 0.421,
#  'grossMargins': 0.41342,
#  'ebitdaMargins': 0.085039996,
#  'operatingMargins': 0.053000003,
#  'financialCurrency': 'INR',
#  'trailingPegRatio': None}
